# %% [markdown]
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>
#
# # Using a pool of workers
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>
#
# In many situations we have J jobs to do and P processors available.  If each job takes $T_j$ time, it would helpful to have an automated procedure for launching jobs on processes in such a way that each process uses approximately $W_p$ total work, where
#
# \begin{equation*}
# W_p \approx \frac{1}{P}\sum_{j=1}^J T_j \qquad p = 1,2,...,P
# \end{equation*}
#
# The `multiprocessing` module's Pool object solves this problem.
#
# If we have several jobs which we expect to take unequal lengths of time to process, we can use a *pool* of workers.  The advantage of this approach is that the processes will be automatically launched, and results automatically collected and returned.  The steps in launching a pool are as follows :
#
# 1.  Decide on how many *tasks* should be launched (`njobs`)
#
# 2.  Decide on how many *processes* should be launched (`nprocs`)
#
# 3.  Define functions that should be called when defining a worker process or processes (`worker`).
#
# 4.  Launch the pool of workers.  There are two conceptual ways to launch jobs:
#
#     * Use `apply` or `apply_async`.  This will launch a single job, with a single argument, using a process from the pool.   Multiple processes can be launched with multiple calls to `apply` or `apply_async`.
#
#     * Use `map` or `map_async`.  This will launch multiple jobs to run the same task on an  *iterable* object (array, list, zip object, and so on).
#
# Here are four sample codes.  The function to be applied in each case is `f`, with an array of `njobs` tuples `data`.  In each case, the Pool is defined as
# <pre><code>
# pool = multiprocessing.Pool(processes=nprocs)
# </code></pre>
#
# For all examples, the results from all processes are stored in `results`.
#
# <hr/>
#
# ### Example 1 : Blocking code using `Pool.map`
#
# <pre><code>
# # Blocks until all results are ready
# results = pool.map(func=f, iterable=data)
# </code></pre>
#
# <hr/>
#
# ### Example 2 : Non-blocking code using `Pool.map_async`
# Results can be processed as they become available using a `callback` function.
#
# <pre><code>
# # Non-blocking code.  Results can be processed by a callback.
# async_results = pool.map_async(func=f, iterable=data,
#     callback=cb)
#
# # Blocks until results are ready
# results = async_results.get()
# </code></pre>
#
# <hr/>
#
# ### Example 3 : Blocking code using `Pool.apply`
# Code will run sequentially - probably not what we want for parallel computing!
# <html><pre><code>
# results = []
# for d in data:
#     # Blocks until job is done
#     r = pool.apply(func=worker, args=(d,))
#     results.append(r)
# </code></pre></html>
#
# <hr/>
#
# ### Example 4 :  Non-blocking code using `Pool.apply_async`
# We can use a `callback` to process the results as they become available.
# <pre><code>
# async_results = []
# for d in data:
#     # Non-blocking calls
#     r = pool.apply_async(func=f,args=(d,),callback=cb)
#     async_results.append(r)
#
# # Blocks until results are ready
# results = [r.get() for r in async_results]
# </code></pre>
#
# Two additional examples illustrate how to distribute tasks using `chunksize` (Example 5) and how to use a callback function to process results as they become
# available (Example 6).

# %% [markdown]
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>
#
# ## Sample results explained
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>

# %% [markdown]
# The following results are typical results obtained using the `Pool.map_async` call.
# <pre><code>
# Launching 19 jobs on 8 cores
# In process 4916 ( 0) is sleeping   4.8323 seconds
# In process 4918 ( 2) is sleeping   0.0375 seconds
# In process 4921 ( 5) is sleeping   2.9111 seconds
# In process 4917 ( 1) is sleeping   2.2037 seconds
# In process 4922 ( 6) is sleeping   3.3578 seconds
# In process 4920 ( 4) is sleeping   4.6963 seconds
# In process 4919 ( 3) is sleeping   4.5549 seconds
# In process 4923 ( 7) is sleeping   0.4197 seconds
# In process 4918 ( 8) is sleeping   3.8324 seconds
# In process 4923 ( 9) is sleeping   1.1840 seconds
# In process 4923 (10) is sleeping   0.1541 seconds
# In process 4923 (11) is sleeping   3.9439 seconds
# In process 4917 (12) is sleeping   1.7304 seconds
# In process 4921 (13) is sleeping   3.1164 seconds
# In process 4922 (14) is sleeping   3.0791 seconds
# In process 4918 (15) is sleeping   0.7428 seconds
# In process 4917 (16) is sleeping   0.9155 seconds
# In process 4919 (17) is sleeping   0.5721 seconds
# In process 4918 (18) is sleeping   0.0731 seconds
# <br/>
# Total time spent in each process
# Process  1 (4916)    4.8323(s)    1 job(s) (0,)
# Process  2 (4917)    4.8496(s)    3 job(s) (1, 12, 16)
# Process  3 (4918)    4.6857(s)    4 job(s) (2, 8, 15, 18)
# Process  4 (4919)    5.1269(s)    2 job(s) (3, 17)
# Process  5 (4920)    4.6963(s)    1 job(s) (4,)
# Process  6 (4921)    6.0275(s)    2 job(s) (5, 13)
# Process  7 (4922)    6.4369(s)    2 job(s) (6, 14)
# Process  8 (4923)    5.7017(s)    4 job(s) (7, 9, 10, 11)
#
#       Total work done (s)      42.3570
#       Wall clock time (s)       6.4890
# </code></pre>
# The first set of results (19 lines) is printed for each job launched and
# provides the process PID (decided by the OS), the task number (0-18), and the time spent in each job.   This information is printed as jobs are launched.
#
# The second set of results (8 lines) collects process information and provides the processor number (1-8) and PID, the total time spent in that process, the number of jobs launched on that processor, and the job numbers launched on that processor.
#
# **Observations.** The first set of results (first 19 lines) are printed as jobs are launched and illustrates the `asynchronous` nature of the call.  Jobs do not necessarily start processing as soon as they are launched.  For example, jobs 2 and 5 are started before job 1.  On the other hand, if we were to sort this list on job number, we would see that jobs are launched on our 8 processors in order.  Here are the first several jobs taken from the top of a list sorted on job number.
#
# <pre><code>
# In process 4916 ( 0) is sleeping   4.8323 seconds
# In process 4917 ( 1) is sleeping   2.2037 seconds
# In process 4918 ( 2) is sleeping   0.0375 seconds
# In process 4919 ( 3) is sleeping   4.5549 seconds
# In process 4920 ( 4) is sleeping   4.6963 seconds
# In process 4921 ( 5) is sleeping   2.9111 seconds
# In process 4922 ( 6) is sleeping   3.3578 seconds
# In process 4923 ( 7) is sleeping   0.4197 seconds
# In process 4918 ( 8) is sleeping   3.8324 seconds
# In process 4923 ( 9) is sleeping   1.1840 seconds
# ....
# </code></pre>
# The first 8 jobs (jobnums 0-7) are launched in order on processors 4916-4923, but the 9th job (jobnum=8) is launched on process 4918, the first processor available (jobs on 4916 and 4917 were still processing).  Similarly, job 10 (jobnum=9) is launched on the next avalailable processor 4923.
#
# Post-processing the results (second 8 lines), we see that to achieve approximately the same amount of time per processor (i.e. *load balancing*), jobs are distributed unequally.  To achieve an approximate time of 5s per process, processors 1 and 5 were only able to processs 1 job, whereas processors 3 and 8 were able to process 4 jobs each.

# %% [markdown]
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>
#
# ## Python modules used for all examples
#
# The following creates and saves the module `pool_tools.py`, used by all example.   The magic command `%%file` creates the indicated file.

# %%
# %%file pool_tools.py
from multiprocessing import Pool
import time, os, random

def worker(z):
    jobnum, t = z    # Distribute tuple to variables.
    id = os.getpid()
    print("In process {} ({:2d}) is sleeping {:8.4f} seconds".format(id,jobnum,t))
    time.sleep(t)
    return (jobnum,t,os.getpid())

def print_pool_results(res,np):
    # how much time was spent in each process? 
    pids = sorted(set([z[2] for z in res]))    # Get a unique set of PIDs
    print("")
    print("Total time spent in each process")
    total_time = 0
    for i,p in enumerate(pids):
        proc_count = sum([1 for z in res if z[2] == p])
        proc_time  = sum([z[1] for z in res if z[2] == p])
        proc_jobs  = tuple([z[0] for z in res if z[2] == p])
        print("Process {:2d} ({})  {:8.4f}(s) {:4d} job(s) {}"
              .format(i+1,p,proc_time,proc_count,proc_jobs))
        total_time += proc_time
    print("")
    print("{:>25s} {:12.4f}".format("Total work done (s)",total_time))
# Out:
# Overwriting pool_tools.py

# %% [markdown]
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>
#
# ## Example 1 : pool.map(func=f,iterable=data)
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>

# %%
from pool_tools import *

def test1(data,np):
    pool = Pool(processes=np)              

    # This function blocks until results are available
    results = pool.map(func=worker,iterable=data)
    print_pool_results(results,np)
    
np = 8
njobs = 19
            
print("Launching {} jobs on {} cores".format(njobs,np))
    
random.seed(1234)

sleep_times = [5*random.random() for i in range(njobs)]
data = zip(range(njobs),sleep_times)    # Create list of tuples (jobid,t)
    
tr = %timeit -n 1 -r 1 -o -q pass; test1(data,np)
print("{:>25s} {:12.4f}".format("Wall clock time (s)",tr.best))
# Out:
# Launching 19 jobs on 8 cores
# In process 4976 ( 0) is sleeping   4.8323 seconds
# In process 4978 ( 2) is sleeping   0.0375 seconds
# In process 4977 ( 1) is sleeping   2.2037 seconds
# In process 4979 ( 3) is sleeping   4.5549 seconds
# In process 4980 ( 4) is sleeping   4.6963 seconds
# In process 4981 ( 5) is sleeping   2.9111 seconds
# In process 4982 ( 6) is sleeping   3.3578 seconds
# In process 4983 ( 7) is sleeping   0.4197 seconds
# In process 4978 ( 8) is sleeping   3.8324 seconds
# In process 4983 ( 9) is sleeping   1.1840 seconds
# In process 4983 (10) is sleeping   0.1541 seconds
# In process 4983 (11) is sleeping   3.9439 seconds
# In process 4977 (12) is sleeping   1.7304 seconds
# In process 4981 (13) is sleeping   3.1164 seconds
# In process 4982 (14) is sleeping   3.0791 seconds
# In process 4978 (15) is sleeping   0.7428 seconds
# In process 4977 (16) is sleeping   0.9155 seconds
# In process 4979 (17) is sleeping   0.5721 seconds
# In process 4978 (18) is sleeping   0.0731 seconds
#
# Total time spent in each process
# Process  1 (4976)    4.8323(s)    1 job(s) (0,)
# Process  2 (4977)    4.8496(s)    3 job(s) (1, 12, 16)
# Process  3 (4978)    4.6857(s)    4 job(s) (2, 8, 15, 18)
# Process  4 (4979)    5.1269(s)    2 job(s) (3, 17)
# Process  5 (4980)    4.6963(s)    1 job(s) (4,)
# Process  6 (4981)    6.0275(s)    2 job(s) (5, 13)
# Process  7 (4982)    6.4369(s)    2 job(s) (6, 14)
# Process  8 (4983)    5.7017(s)    4 job(s) (7, 9, 10, 11)
#
#       Total work done (s)      42.3570
#       Wall clock time (s)       6.4807

# %% [markdown]
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>
#
# ## Example 2 : pool.map_async(func=f,iterable=data)
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>

# %%
from pool_tools import *

def test2(data,np):
    pool = Pool(processes=np)              
    
    # This is non-blocking
    async_results = pool.map_async(func=worker,iterable=data)
    
    # This call blocks until all results are available
    results = async_results.get()   
    
    print_pool_results(results,np)
    
np = 8
njobs = 19
            
print("Launching {} jobs on {} cores".format(njobs,np))
    
random.seed(1234)

sleep_times = [5*random.random() for i in range(njobs)]
data = zip(range(njobs),sleep_times)    # Create list of tuples (p,t)
    
tr = %timeit -n 1 -r 1 -o -q pass; test2(data,np)
print("{:>25s} {:12.4f}".format("Wall clock time (s)",tr.best))
# Out:
# Launching 19 jobs on 8 cores
# In process 4984 ( 0) is sleeping   4.8323 seconds
# In process 4985 ( 1) is sleeping   2.2037 seconds
# In process 4988 ( 4) is sleeping   4.6963 seconds
# In process 4986 ( 2) is sleeping   0.0375 seconds
# In process 4987 ( 3) is sleeping   4.5549 seconds
# In process 4989 ( 5) is sleeping   2.9111 seconds
# In process 4991 ( 7) is sleeping   0.4197 seconds
# In process 4990 ( 6) is sleeping   3.3578 seconds
# In process 4986 ( 8) is sleeping   3.8324 seconds
# In process 4991 ( 9) is sleeping   1.1840 seconds
# In process 4991 (10) is sleeping   0.1541 seconds
# In process 4991 (11) is sleeping   3.9439 seconds
# In process 4985 (12) is sleeping   1.7304 seconds
# In process 4989 (13) is sleeping   3.1164 seconds
# In process 4990 (14) is sleeping   3.0791 seconds
# In process 4986 (15) is sleeping   0.7428 seconds
# In process 4985 (16) is sleeping   0.9155 seconds
# In process 4987 (17) is sleeping   0.5721 seconds
# In process 4986 (18) is sleeping   0.0731 seconds
#
# Total time spent in each process
# Process  1 (4984)    4.8323(s)    1 job(s) (0,)
# Process  2 (4985)    4.8496(s)    3 job(s) (1, 12, 16)
# Process  3 (4986)    4.6857(s)    4 job(s) (2, 8, 15, 18)
# Process  4 (4987)    5.1269(s)    2 job(s) (3, 17)
# Process  5 (4988)    4.6963(s)    1 job(s) (4,)
# Process  6 (4989)    6.0275(s)    2 job(s) (5, 13)
# Process  7 (4990)    6.4369(s)    2 job(s) (6, 14)
# Process  8 (4991)    5.7017(s)    4 job(s) (7, 9, 10, 11)
#
#       Total work done (s)      42.3570
#       Wall clock time (s)       6.4872

# %% [markdown]
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>
#
# ## Example 3 : pool.apply(func = f,args = data)
#
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>
#
# Using this mode, jobs are launched in order and run sequentially.  Jobs are not run in parallel.

# %%
from pool_tools import *

def test3(data,np):
    pool = Pool(processes=np)          

    results = []
    for d in data:
        # This call is blocking;  jobs run sequentially
        r = pool.apply(worker,args=(d,))
        results.append(r)
    
    print_pool_results(results,np)
    
np = 8
njobs = 19
            
print("Launching {} jobs on {} cores".format(njobs,np))
    
random.seed(1234)

sleep_times = [5*random.random() for i in range(njobs)]
pnum = range(njobs)
data = zip(pnum,sleep_times)
    
tr = %timeit -n 1 -r 1 -o -q pass; test3(data,np)
print("{:>25s} {:12.4f}".format("Wall clock time (s)",tr.best))
# Out:
# Launching 19 jobs on 8 cores
# In process 5007 ( 0) is sleeping   4.8323 seconds
# In process 5008 ( 1) is sleeping   2.2037 seconds
# In process 5009 ( 2) is sleeping   0.0375 seconds
# In process 5010 ( 3) is sleeping   4.5549 seconds
# In process 5011 ( 4) is sleeping   4.6963 seconds
# In process 5012 ( 5) is sleeping   2.9111 seconds
# In process 5013 ( 6) is sleeping   3.3578 seconds
# In process 5014 ( 7) is sleeping   0.4197 seconds
# In process 5007 ( 8) is sleeping   3.8324 seconds
# In process 5008 ( 9) is sleeping   1.1840 seconds
# In process 5009 (10) is sleeping   0.1541 seconds
# In process 5010 (11) is sleeping   3.9439 seconds
# In process 5011 (12) is sleeping   1.7304 seconds
# In process 5012 (13) is sleeping   3.1164 seconds
# In process 5013 (14) is sleeping   3.0791 seconds
# In process 5014 (15) is sleeping   0.7428 seconds
# In process 5007 (16) is sleeping   0.9155 seconds
# In process 5008 (17) is sleeping   0.5721 seconds
# In process 5009 (18) is sleeping   0.0731 seconds
#
# Total time spent in each process
# Process  1 (5007)    9.5801(s)    3 job(s) (0, 8, 16)
# Process  2 (5008)    3.9598(s)    3 job(s) (1, 9, 17)
# Process  3 (5009)    0.2646(s)    3 job(s) (2, 10, 18)
# Process  4 (5010)    8.4987(s)    2 job(s) (3, 11)
# Process  5 (5011)    6.4268(s)    2 job(s) (4, 12)
# Process  6 (5012)    6.0275(s)    2 job(s) (5, 13)
# Process  7 (5013)    6.4369(s)    2 job(s) (6, 14)
# Process  8 (5014)    1.1625(s)    2 job(s) (7, 15)
#
#       Total work done (s)      42.3570
#       Wall clock time (s)      42.4909

# %% [markdown]
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>
#
# ## Example 4 : pool.apply_async(func=f,args=data)
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>

# %%
from pool_tools import *

def test4(data,np):
    pool = Pool(processes=np)             

    # This call is non-blocking;  
    async_results = []
    for d in data:
        r = pool.apply_async(worker,args = (d,))
        async_results.append(r)
    pool.close()
    pool.join()     # Block here or with r.get() below
    results = [r.get() for r in async_results]  # this blocks if pool is not closed/joined
    print_pool_results(results,np)
    
np = 8
njobs = 19
            
print("Launching {} jobs on {} cores".format(njobs,np))
    
random.seed(1234)

sleep_times = [5*random.random() for i in range(njobs)]
pnum = range(njobs)
data = zip(pnum,sleep_times)
    
tr = %timeit -n 1 -r 1 -o -q pass; test4(data,np)
print("{:>25s} {:12.4f}".format("Wall clock time (s)",tr.best))
# Out:
# Launching 19 jobs on 8 cores
# In process 5062 ( 2) is sleeping   0.0375 seconds
# In process 5066 ( 6) is sleeping   3.3578 seconds
# In process 5060 ( 0) is sleeping   4.8323 seconds
# In process 5061 ( 1) is sleeping   2.2037 seconds
# In process 5063 ( 3) is sleeping   4.5549 seconds
# In process 5064 ( 4) is sleeping   4.6963 seconds
# In process 5065 ( 5) is sleeping   2.9111 seconds
# In process 5067 ( 7) is sleeping   0.4197 seconds
# In process 5062 ( 8) is sleeping   3.8324 seconds
# In process 5067 ( 9) is sleeping   1.1840 seconds
# In process 5067 (10) is sleeping   0.1541 seconds
# In process 5067 (11) is sleeping   3.9439 seconds
# In process 5061 (12) is sleeping   1.7304 seconds
# In process 5065 (13) is sleeping   3.1164 seconds
# In process 5066 (14) is sleeping   3.0791 seconds
# In process 5062 (15) is sleeping   0.7428 seconds
# In process 5061 (16) is sleeping   0.9155 seconds
# In process 5063 (17) is sleeping   0.5721 seconds
# In process 5062 (18) is sleeping   0.0731 seconds
#
# Total time spent in each process
# Process  1 (5060)    4.8323(s)    1 job(s) (0,)
# Process  2 (5061)    4.8496(s)    3 job(s) (1, 12, 16)
# Process  3 (5062)    4.6857(s)    4 job(s) (2, 8, 15, 18)
# Process  4 (5063)    5.1269(s)    2 job(s) (3, 17)
# Process  5 (5064)    4.6963(s)    1 job(s) (4,)
# Process  6 (5065)    6.0275(s)    2 job(s) (5, 13)
# Process  7 (5066)    6.4369(s)    2 job(s) (6, 14)
# Process  8 (5067)    5.7017(s)    4 job(s) (7, 9, 10, 11)
#
#       Total work done (s)      42.3570
#       Wall clock time (s)       6.5506

# %% [markdown]
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>
#
# ## Example 5 : Controlling how tasks are distributed
#
# We can have some control over how tasks are handed off to processors using the `chunksize` keyword.  Setting `chunksize=4` when calling `map_async` for example, the pool will put the first four tasks on the first processor, the second four tasks on the second processor, and so on.
#
# Increasing the chunksize from the default value of 1 can improve performance, depending on the application.
#
# If not done with some reasonable care, increasing chunksize can have the following disadvantages :
#
# * This can lead to very bad load balancing.
# * Some processors in the pool may not get used at all.
#
# In the following example, we create 23 tasks for 8 processors, with a chunksize of 4.  With this configuration, 5 processors will get 4 tasks each, 1 processor will get 3 tasks, and 2 processors will remain idle.

# %%
from pool_tools import  *

def test5(data,np):
    pool = Pool(processes=np)              

    # This function blocks until results 'res' are available
    async_results = pool.map_async(func=worker,iterable=data,chunksize=4)
    results = async_results.get()
    print_pool_results(results,np)
    
np = 8
njobs = 19
            
print("Launching {} jobs on {} cores".format(njobs,np))
    
random.seed(1234)

sleep_times = [5*random.random() for i in range(njobs)]
data = zip(range(njobs),sleep_times)    # Create list of tuples (p,t)
    
tr = %timeit -n 1 -r 1 -o -q pass; test5(data,np)
print("{:>25s} {:12.4f}".format("Wall clock time (s)",tr.best))
# Out:
# Launching 19 jobs on 8 cores
# In process 5068 ( 0) is sleeping   4.8323 seconds
# In process 5072 (16) is sleeping   0.9155 seconds
# In process 5071 (12) is sleeping   1.7304 seconds
# In process 5070 ( 8) is sleeping   3.8324 seconds
# In process 5069 ( 4) is sleeping   4.6963 seconds
# In process 5072 (17) is sleeping   0.5721 seconds
# In process 5072 (18) is sleeping   0.0731 seconds
# In process 5071 (13) is sleeping   3.1164 seconds
# In process 5070 ( 9) is sleeping   1.1840 seconds
# In process 5069 ( 5) is sleeping   2.9111 seconds
# In process 5068 ( 1) is sleeping   2.2037 seconds
# In process 5071 (14) is sleeping   3.0791 seconds
# In process 5070 (10) is sleeping   0.1541 seconds
# In process 5070 (11) is sleeping   3.9439 seconds
# In process 5068 ( 2) is sleeping   0.0375 seconds
# In process 5068 ( 3) is sleeping   4.5549 seconds
# In process 5069 ( 6) is sleeping   3.3578 seconds
# In process 5071 (15) is sleeping   0.7428 seconds
# In process 5069 ( 7) is sleeping   0.4197 seconds
#
# Total time spent in each process
# Process  1 (5068)   11.6283(s)    4 job(s) (0, 1, 2, 3)
# Process  2 (5069)   11.3850(s)    4 job(s) (4, 5, 6, 7)
# Process  3 (5070)    9.1144(s)    4 job(s) (8, 9, 10, 11)
# Process  4 (5071)    8.6687(s)    4 job(s) (12, 13, 14, 15)
# Process  5 (5072)    1.5606(s)    3 job(s) (16, 17, 18)
#
#       Total work done (s)      42.3570
#       Wall clock time (s)      11.6813

# %% [markdown]
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>
#
# ## Example 6 : Using a callback to process results
#
# In this example, we use a callback to process results as they become available.  Notice that results are available even before all jobs have been launched.  Also in this example, we illustrate the idea that the main program can be doing work while we are waiting for all jobs to complete.
#
# The callback takes the result returned from our worker process and computes both the total job time (`rt`) taken so far, and total wall-clock (`wc`) time.  Since we are running on multiple processors, we expect `rt` $>$ `wc`.
#
# **Note:**  For this example, we have increased the time spent in each process to some value in $[0,30]$ (rather than $[0,5]$ in previous examples.

# %%
from pool_tools import *

# Process results right away.
running_total = 0
def cb(res):
    global t0, running_total
    r = res
    t1 = time.time()
    wc = t1-t0
    running_total += r[1]
    print("Process {}, job {:2d} is done in {:8.4f} (s) (wc/rt {:8.2f}/{:.2f})".
          format(r[2],r[0],r[1],wc,running_total))

def test6(data,np):
    pool = Pool(processes=np)              # start 4 worker processes

    # This call is non-blocking;  
    async_results = []
    for d in data:
        r = pool.apply_async(func=worker, args=(d,), callback=cb)
        async_results.append(r)
    pool.close()
    print("---> Do some useful work while we are waiting for background jobs.")
    #time.sleep(25)
    print("---> Done with our other work !!!")
    pool.join()     # Block here or with r.get() below
    results = [r.get() for r in async_results]  # this blocks if pool is not closed/joined
    print_pool_results(results,np)
    
np = 8
njobs = 19
            
print("Launching {} jobs on {} cores".format(njobs,np))
    
random.seed(1234)

sleep_times = [5*random.random() for i in range(njobs)]
pnum = range(njobs)
data = zip(pnum,sleep_times)
    
t0 = time.time()
tr = %timeit -n 1 -r 1 -o -q pass; test6(data,np)
print("{:>25s} {:12.4f}".format("Wall clock time (s)",tr.best))
# Out:
# Launching 19 jobs on 8 cores
# In process 5126 ( 0) is sleeping   4.8323 seconds
# In process 5128 ( 2) is sleeping   0.0375 seconds
# In process 5130 ( 4) is sleeping   4.6963 seconds
# In process 5129 ( 3) is sleeping   4.5549 seconds
# In process 5131 ( 5) is sleeping   2.9111 seconds
# In process 5127 ( 1) is sleeping   2.2037 seconds
# In process 5132 ( 6) is sleeping   3.3578 seconds
# In process 5133 ( 7) is sleeping   0.4197 seconds
# In process 5128 ( 8) is sleeping   3.8324 seconds
# ---> Do some useful work while we are waiting for background jobs.
# ---> Done with our other work !!!
# Process 5128, job  2 is done in   0.0375 (s) (wc/rt     0.09/0.04)
# In process 5133 ( 9) is sleeping   1.1840 seconds
# Process 5133, job  7 is done in   0.4197 (s) (wc/rt     0.47/0.46)
# In process 5133 (10) is sleeping   0.1541 seconds
# In process 5133 (11) is sleeping   3.9439 seconds
# Process 5133, job  9 is done in   1.1840 (s) (wc/rt     1.66/1.64)
# Process 5133, job 10 is done in   0.1541 (s) (wc/rt     1.82/1.80)
# In process 5127 (12) is sleeping   1.7304 seconds
# Process 5127, job  1 is done in   2.2037 (s) (wc/rt     2.25/4.00)
# In process 5131 (13) is sleeping   3.1164 seconds
# Process 5131, job  5 is done in   2.9111 (s) (wc/rt     2.96/6.91)
# In process 5132 (14) is sleeping   3.0791 seconds
# Process 5132, job  6 is done in   3.3578 (s) (wc/rt     3.41/10.27)
# In process 5128 (15) is sleeping   0.7428 seconds
# In process 5127 (16) is sleeping   0.9155 seconds
# Process 5128, job  8 is done in   3.8324 (s) (wc/rt     3.92/14.10)
# Process 5127, job 12 is done in   1.7304 (s) (wc/rt     3.99/15.83)
# In process 5129 (17) is sleeping   0.5721 seconds
# In process 5128 (18) is sleeping   0.0731 seconds
# Process 5129, job  3 is done in   4.5549 (s) (wc/rt     4.60/20.39)
# Process 5128, job 15 is done in   0.7428 (s) (wc/rt     4.67/21.13)
# Process 5130, job  4 is done in   4.6963 (s) (wc/rt     4.74/25.82)
# Process 5128, job 18 is done in   0.0731 (s) (wc/rt     4.74/25.90)
# Process 5126, job  0 is done in   4.8323 (s) (wc/rt     4.88/30.73)
# Process 5127, job 16 is done in   0.9155 (s) (wc/rt     4.90/31.65)
# Process 5129, job 17 is done in   0.5721 (s) (wc/rt     5.18/32.22)
# Process 5133, job 11 is done in   3.9439 (s) (wc/rt     5.77/36.16)
# Process 5131, job 13 is done in   3.1164 (s) (wc/rt     6.08/39.28)
# Process 5132, job 14 is done in   3.0791 (s) (wc/rt     6.49/42.36)
#
# Total time spent in each process
# Process  1 (5126)    4.8323(s)    1 job(s) (0,)
# Process  2 (5127)    4.8496(s)    3 job(s) (1, 12, 16)
# Process  3 (5128)    4.6857(s)    4 job(s) (2, 8, 15, 18)
# Process  4 (5129)    5.1269(s)    2 job(s) (3, 17)
# Process  5 (5130)    4.6963(s)    1 job(s) (4,)
# Process  6 (5131)    6.0275(s)    2 job(s) (5, 13)
# Process  7 (5132)    6.4369(s)    2 job(s) (6, 14)
# Process  8 (5133)    5.7017(s)    4 job(s) (7, 9, 10, 11)
#
#       Total work done (s)      42.3570
#       Wall clock time (s)       6.5429

# %% [markdown]
# <hr style="border-width:4px; border-color:coral; border-style:solid" hr/>
#
# ## Example 7 : Using a Process
#
# In this example, we use the original multiprocessing Process to fork processes.
# As the results show, the underlying operating system may be the best scheduler!

# %%
from pool_tools import *

from multiprocessing import Pool, Process, Pipe
import time, os, random

def worker_pipe(d,p1):
    jobnum, t = d    # Distribute tuple to variables.
    id = os.getpid()
    print("In process {} ({:2d}) is sleeping {:8.4f} seconds".format(id,jobnum,t))
    time.sleep(t)
    p1.send((jobnum,t,os.getpid()))

    
def test7(data,np):
    pool = Pool(processes=np)              # start 4 worker processes

    jobs = []
    pipes = []
    for d in data:
        p0,p1 = Pipe()
        job = Process(target=worker_pipe,args=(d,p1))
        job.start()
        jobs.append(job)
        pipes.append(p0)
        
    results = []
    for p1 in pipes:
        r = p1.recv()
        results.append(r)
        p1.close()
        
    print_pool_results(results,np)

    
np = 8
njobs = 19
            
print("Launching {} jobs on {} cores".format(njobs,np))
    
random.seed(1234)

sleep_times = [5*random.random() for i in range(njobs)]
pnum = range(njobs)
data = zip(pnum,sleep_times)
    
t0 = time.time()
tr = %timeit -n 1 -r 1 -o -q pass; test7(data,np)
print("{:>25s} {:12.4f}".format("Wall clock time (s)",tr.best))
# Out:
# Launching 19 jobs on 8 cores
# In process 5157 ( 0) is sleeping   4.8323 seconds
# In process 5158 ( 1) is sleeping   2.2037 seconds
# In process 5159 ( 2) is sleeping   0.0375 seconds
# In process 5160 ( 3) is sleeping   4.5549 seconds
# In process 5161 ( 4) is sleeping   4.6963 seconds
# In process 5162 ( 5) is sleeping   2.9111 seconds
# In process 5163 ( 6) is sleeping   3.3578 seconds
# In process 5164 ( 7) is sleeping   0.4197 seconds
# In process 5165 ( 8) is sleeping   3.8324 seconds
# In process 5166 ( 9) is sleeping   1.1840 seconds
# In process 5167 (10) is sleeping   0.1541 seconds
# In process 5168 (11) is sleeping   3.9439 seconds
# In process 5169 (12) is sleeping   1.7304 seconds
# In process 5170 (13) is sleeping   3.1164 seconds
# In process 5171 (14) is sleeping   3.0791 seconds
# In process 5172 (15) is sleeping   0.7428 seconds
# In process 5173 (16) is sleeping   0.9155 seconds
# In process 5174 (17) is sleeping   0.5721 seconds
# In process 5175 (18) is sleeping   0.0731 seconds
#
# Total time spent in each process
# Process  1 (5157)    4.8323(s)    1 job(s) (0,)
# Process  2 (5158)    2.2037(s)    1 job(s) (1,)
# Process  3 (5159)    0.0375(s)    1 job(s) (2,)
# Process  4 (5160)    4.5549(s)    1 job(s) (3,)
# Process  5 (5161)    4.6963(s)    1 job(s) (4,)
# Process  6 (5162)    2.9111(s)    1 job(s) (5,)
# Process  7 (5163)    3.3578(s)    1 job(s) (6,)
# Process  8 (5164)    0.4197(s)    1 job(s) (7,)
# Process  9 (5165)    3.8324(s)    1 job(s) (8,)
# Process 10 (5166)    1.1840(s)    1 job(s) (9,)
# Process 11 (5167)    0.1541(s)    1 job(s) (10,)
# Process 12 (5168)    3.9439(s)    1 job(s) (11,)
# Process 13 (5169)    1.7304(s)    1 job(s) (12,)
# Process 14 (5170)    3.1164(s)    1 job(s) (13,)
# Process 15 (5171)    3.0791(s)    1 job(s) (14,)
# Process 16 (5172)    0.7428(s)    1 job(s) (15,)
# Process 17 (5173)    0.9155(s)    1 job(s) (16,)
# Process 18 (5174)    0.5721(s)    1 job(s) (17,)
# Process 19 (5175)    0.0731(s)    1 job(s) (18,)
#
#       Total work done (s)      42.3570
#       Wall clock time (s)       4.8955
